# %%
# simulate
#fig8
import matplotlib.pyplot as plt
import math
# %matplotlib inline
import numpy as np
# paras
h1 = 2.5; h2 = 2; x12 = 0.05; x21=0.03 ;ta=600 ;r=3000 ;T=600 ;p=0.1;r0=1500;k=1.5;q=1.2;n=1000
x1 = 0.6
x2 = (1 - x1)
n1=x1*n
nm=0.1*n1
na=0.9*n1
n2=x2*n
c1=(h1*(x1-x12))+(h2*(x2-x21))
c2=(h1*(x1-x12))-(h2*(x2-x21))
s = np.linspace(-1, 5, 100)

# fitnesses
ms1=((1/(n1*c1))*(r0+(r*s))*(2.71**(-((ta*s)/T))))-p
mqs1=((1/(n1*c1))*(r0+(r*q*s))*(2.71**((-q)*s*(ta/T))))-p
mts2=((1/((n2+nm)*c1))*(h1/h2)*(r0+(r*s))*(2.71**(-(ta*s/T))))-p
#as1=k*ms1
#aqs1=k*mqs1
#as2=((k/((n2+na)*c1))*(h1/h2)*(r0+(r*s2))*(math.exp(-(ta/T))))-(p*k)
#y=10*2.71**s

# Creating vectors X and Y

fig = plt.figure(figsize = (10, 5))

# Create the plot
plt.plot(s, ms1 , "r" , label="RPUm,s")
plt.plot(s, mqs1, "b", label="RPUm,qs")
plt.plot(s, mts2, "k", label="RPU'm,s")
plt.legend(loc = 'best')
plt.ylim(-0.5, 2.5)
#plt.plot(s, y, "o")
# Show the plot
plt.show()

# %%
# simulate
#fig9
import matplotlib.pyplot as plt
import math
# %matplotlib inline
import numpy as np
# paras
h1 = 2.5; h2 = 2; x12 = 0.05; x21=0.03 ;ta=600 ;r=3000 ;T=600 ;p=0.1;r0=1500;k=1.5;q=1.2;n=1000
x1 = 0.6
x2 = (1 - x1)
n1=x1*n
nm=0.1*n1
na=0.9*n1
n2=x2*n
c1=(h1*(x1-x12))+(h2*(x2-x21))
c2=(h1*(x1-x12))-(h2*(x2-x21))
s = np.linspace(-1, 5, 100)

# fitnesses
ms1=((1/(n1*c1))*(r0+(r*s))*(2.71**(-((ta*s)/T))))-p
mqs1=((1/(n1*c1))*(r0+(r*q*s))*(2.71**((-q)*s*(ta/T))))-p
mts2=((1/((n2+nm)*c1))*(h1/h2)*(r0+(r*s))*(2.71**(-(ta*s/T))))-p
as1=k*ms1
aqs1=k*mqs1
as2=((k/((n2+na)*c1))*(h1/h2)*(r0+(r*s))*(2.71**(-(ta*s/T))))-(p*k)
#y=10*2.71**s

# Creating vectors X and Y

fig = plt.figure(figsize = (10, 5))

# Create the plot
plt.plot(s, as1 , "r", label="RPUa,s")
plt.plot(s, aqs1, "b", label="RPUa,qs")
plt.plot(s, as2, "k", label="RPU'm,s")
plt.legend(loc = 'best')
plt.ylim(-0.5, 2.5)
#plt.plot(s, y, "o")
# Show the plot
plt.show()
